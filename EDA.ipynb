# %% [markdown]
# ## Performing Exploratory Data Analysis to understand the Data better

# %% [markdown]
# ### Importing the required libraries

# %%
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPClassifier
from keras.models import Sequential
from keras.layers import Dense
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.svm import SVC
from sklearn.metrics import *
from sklearn.feature_selection import SequentialFeatureSelector

#Supress Sklearn Warnings
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %% [markdown]
# ### Importing the Data

# %%
train = pd.read_csv('algerian_fires_train.csv')
test = pd.read_csv('algerian_fires_test.csv')

# %% [markdown]
# ### Importing our Functions

# %%
from functions import correlation_heatmap

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Checking the Dataset Info

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         184 non-null    object
#  1   Temperature  184 non-null    float64
#  2   RH           184 non-null    float64
#  3   Ws           184 non-null    float64
#  4   Rain         184 non-null    float64
#  5   FFMC         184 non-null    float64
#  6   DMC          184 non-null    float64
#  7   DC           184 non-null    float64
#  8   ISI          184 non-null    float64
#  9   BUI          184 non-null    float64
#  10  Classes      184 non-null    int64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 15.9+ KB

# %% [markdown]
# #### Histogram Plots

# %%
for column in train.columns:
    if column != 'Date':
        sns.displot(train[column],kde=True)

# %% [markdown]
# #### Checking if there any missing values in the dataset

# %%
print(train.isnull().sum())
# Out:
# Date           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# Classes        0
# dtype: int64

# %% [markdown]
# #### Correlation Heatmap

# %%
correlation_heatmap(train)
